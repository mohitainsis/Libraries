# %%
import pandas as pd
import numpy as np
import os

# %%
data = {
    "Name": ["Riya", "Aman", "Raj", "Neha", "Karan", "Simran"],
    "Age": [23, np.nan, 29, 31, np.nan, 26],
    "Salary": [50000, 60000, np.nan, 58000, 62000, np.nan],
    "Department": ["HR", "IT", "Finance", np.nan, "IT", "HR"]
}


data = pd.DataFrame(data)

# %%
data["Age"] = np.nan

# %%
data
# Out:
#      Name  Age   Salary Department
# 0    Riya  NaN  50000.0         HR
# 1    Aman  NaN  60000.0         IT
# 2     Raj  NaN      NaN    Finance
# 3    Neha  NaN  58000.0        NaN
# 4   Karan  NaN  62000.0         IT
# 5  Simran  NaN      NaN         HR

# %%
data.dropna(how="all",axis=1)
# Out:
#      Name   Age   Salary Department
# 0    Riya  23.0  50000.0         HR
# 1    Aman   NaN  60000.0         IT
# 2     Raj  29.0      NaN    Finance
# 3    Neha  31.0  58000.0        NaN
# 4   Karan   NaN  62000.0         IT
# 5  Simran  26.0      NaN         HR

# %%
data["Name"]=np.nan

# %%
data
# Out:
#    Name   Age   Salary Department
# 0   NaN  23.0  50000.0         HR
# 1   NaN   NaN  60000.0         IT
# 2   NaN  29.0      NaN    Finance
# 3   NaN  31.0  58000.0        NaN
# 4   NaN   NaN  62000.0         IT
# 5   NaN  26.0      NaN         HR

# %%
data.dropna(how="all",axis=1)
# Out:
#     Age   Salary Department
# 0  23.0  50000.0         HR
# 1   NaN  60000.0         IT
# 2  29.0      NaN    Finance
# 3  31.0  58000.0        NaN
# 4   NaN  62000.0         IT
# 5  26.0      NaN         HR

# %%
data
# Out:
#    Name   Age   Salary Department
# 0   NaN  23.0  50000.0         HR
# 1   NaN   NaN  60000.0         IT
# 2   NaN  29.0      NaN    Finance
# 3   NaN  31.0  58000.0        NaN
# 4   NaN   NaN  62000.0         IT
# 5   NaN  26.0      NaN         HR

# %%
data_dup = {
    "Name": ["Riya", "Aman", "Raj", "Neha", "Karan", "Simran"],
    "Age": [23, np.nan, 29, 31, np.nan, 26],
    "Salary": [50000, 60000, np.nan, 58000, 62000, np.nan],
    "Department": ["IT", "IT", "IT", "IT", "IT", "IT"]
}
df_dup =pd.DataFrame(data_dup)

# %%
df_dup
# Out:
#      Name   Age   Salary Department
# 0    Riya  23.0  50000.0         IT
# 1    Aman   NaN  60000.0         IT
# 2     Raj  29.0      NaN         IT
# 3    Neha  31.0  58000.0         IT
# 4   Karan   NaN  62000.0         IT
# 5  Simran  26.0      NaN         IT

# %%
df_dup.drop_duplicates(subset="Name")
# Out:
#      Name   Age   Salary Department
# 0    Riya  23.0  50000.0         IT
# 1    Aman   NaN  60000.0         IT
# 2     Raj  29.0      NaN         IT
# 3    Neha  31.0  58000.0         IT
# 4   Karan   NaN  62000.0         IT
# 5  Simran  26.0      NaN         IT

# %%
data = {
    "Name": ["Aman", "Riya", "Aman", "Karan", "Riya"],
    "Age": [23, 25, 23, 24, 25],
    "City": ["Delhi", "Mumbai", "Delhi", "Pune", "Mumbai"]
}
df = pd.DataFrame(data)

# %%
df
# Out:
#     Name  Age    City
# 0   Aman   23   Delhi
# 1   Riya   25  Mumbai
# 2   Aman   23   Delhi
# 3  Karan   24    Pune
# 4   Riya   25  Mumbai

# %%
df.drop_duplicates(subset="Name")
# Out:
#     Name  Age    City
# 0   Aman   23   Delhi
# 1   Riya   25  Mumbai
# 3  Karan   24    Pune

# %%
df[df.duplicated(subset=["Name"],keep=False)]
# Out:
#    Name  Age    City
# 0  Aman   23   Delhi
# 1  Riya   25  Mumbai
# 2  Aman   23   Delhi
# 4  Riya   25  Mumbai

# %%
data = pd.read_csv("actuals")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[36], line 1
# ----> 1 data = pd.read_csv("actuals")
#
# File c:\Users\Thisi\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\io\parsers\readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
# ...

# %%
data = pd.read_excel(r"C:\Users\Thisi\OneDrive\Documents\datasets\Dataset 1\orders.xlsx")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[46], line 1
# ----> 1 data = pd.read_excel(r"C:\Users\Thisi\OneDrive\Documents\datasets\Dataset 1\orders.xlsx")
#
# File c:\Users\Thisi\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\io\excel\_base.py:495, in read_excel(io, sheet_name, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, date_format, thousands, decimal, comment, skipfooter, storage_options, dtype_backend, engine_kwargs)
#     493 if not isinstance(io, ExcelFile):
#     494     should_close = True
# --> 495     io = ExcelFile(
#     496         io,
#     497         storage_options=storage_options,
#     498         engine=engine,
#     499         engine_kwargs=engine_kwargs,
#     500     )
# ...

# %%
df = pd.read_excel(r"C:\Users\Thisi\OneDrive\Documents\datasets\Dataset 1\orders.xlsx")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[48], line 1
# ----> 1 df = pd.read_excel(r"C:\Users\Thisi\OneDrive\Documents\datasets\Dataset 1\orders.xlsx")
#
# File c:\Users\Thisi\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\io\excel\_base.py:495, in read_excel(io, sheet_name, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, date_format, thousands, decimal, comment, skipfooter, storage_options, dtype_backend, engine_kwargs)
#     493 if not isinstance(io, ExcelFile):
#     494     should_close = True
# --> 495     io = ExcelFile(
#     496         io,
#     497         storage_options=storage_options,
#     498         engine=engine,
#     499         engine_kwargs=engine_kwargs,
#     500     )
# ...

# %%
os.listdir(r"C:\Users\Thisi\OneDrive\Documents\datasets\Dataset 1")
# Out:
# ['category.csv',
#  'class.csv',
#  'groups.csv',
#  'membership.csv',
#  'orders.xlsx.csv',
#  'order_details.csv',
#  'person1.csv',
#  'person2.csv',
#  'students.csv',
#  'users.csv',
#  'users1.csv']

# %%
data = pd.read_csv(r"C:\Users\Thisi\OneDrive\Documents\datasets\Dataset 1\order_details.csv")

# %%
data
# Out:
#      order_id  amount  profit  quantity  category_id
# 0     B-25601  1275.0 -1148.0         7            1
# 1     B-25614   494.0    54.0         4            1
# 2     B-25618   362.0   127.0         1            1
# 3     B-25638   182.0   -11.0         3            1
# 4     B-25643  1061.0   -36.0         8            1
# ...       ...     ...     ...       ...          ...
# 1495  B-26053    17.0     1.0         2           65
# 1496  B-26053    27.0     6.0         3           65
# 1497  B-26078    17.0     8.0         2           65
# 1498  B-26098    46.0    14.0         5           65
# 1499  B-26099     9.0     3.0         1           65
#
# [1500 rows x 5 columns]

# %%
df = pd.read_excel(r"C:\Users\Thisi\Downloads\SuperStore Sales Data-20260306T171841Z-3-001\SuperStore Sales Data\Sales_Dataset.xlsx")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# File c:\Users\Thisi\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\compat\_optional.py:135, in import_optional_dependency(name, extra, errors, min_version)
#     134 try:
# --> 135     module = importlib.import_module(name)
#     136 except ImportError:
#
# File c:\Users\Thisi\AppData\Local\Programs\Python\Python313\Lib\importlib\__init__.py:88, in import_module(name, package)
#      87         level += 1
# ---> 88 return _bootstrap._gcd_import(name[level:], package, level)
#
# File <frozen importlib._bootstrap>:1387, in _gcd_import(name, package, level)
#
# File <frozen importlib._bootstrap>:1360, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:1324, in _find_and_load_unlocked(name, import_)
#
# ModuleNotFoundError: No module named 'openpyxl'
#
# ...

# %%
os.listdir(r"C:\Users\Thisi\Downloads\SuperStore Sales Data-20260306T171841Z-3-001\SuperStore Sales Data")
# Out:
# ['blue bg.jpg', 'Sales_DataSet.xlsx', 'SuperStore_Sales_Dataset.csv']

# %%
data = pd.read_excel(r"C:\Users\Thisi\Downloads\SuperStore Sales Data-20260306T171841Z-3-001\SuperStore Sales Data\Sales_Dataset.xlsx")

# %%
data
# Out:
#       Row ID+O6G3A1:R6        Order ID Order Date  Ship Date       Ship Mode  \
# 0                 4918  CA-2019-160304 2019-01-01 2019-01-07  Standard Class
# 1                 4919  CA-2019-160304 2019-01-02 2019-01-07  Standard Class
# 2                 4920  CA-2019-160304 2019-01-02 2019-01-07  Standard Class
# 3                 3074  CA-2019-125206 2019-01-03 2019-01-05     First Class
# 4                 8604  US-2019-116365 2019-01-03 2019-01-08  Standard Class
# ...                ...             ...        ...        ...             ...
# 5896               907  CA-2020-143259 2020-12-30 2021-01-03  Standard Class
# 5897              1297  CA-2020-115427 2020-12-30 2021-01-03  Standard Class
# 5898              5092  CA-2020-156720 2020-12-30 2021-01-03  Standard Class
# 5899               909  CA-2020-143259 2020-12-30 2021-01-03  Standard Class
# 5900              5093  CA-2020-151450 2020-12-31 2021-01-04  Standard Class
#
# ...

# %%
df.shape()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[64], line 1
# ----> 1 df.shape()
#
# TypeError: 'tuple' object is not callable

# %%
data.shape(

)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[65], line 1
# ----> 1 data.shape(
#       2
#       3 )
#
# TypeError: 'tuple' object is not callable

# %%
data.shape
# Out:
# (5901, 23)

# %%
df.columns
# Out:
# Index(['Name', 'Age', 'City'], dtype='object')

# %%
dff.info()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[68], line 1
# ----> 1 dff.info()
#
# NameError: name 'dff' is not defined

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Name    5 non-null      object
#  1   Age     5 non-null      int64
#  2   City    5 non-null      object
# dtypes: int64(1), object(2)
# memory usage: 252.0+ bytes

# %%
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 df
#
# NameError: name 'df' is not defined

# %%
dd
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 dd
#
# NameError: name 'dd' is not defined

# %%
data = pd.DataFrame("pr1_ds")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 data = pd.DataFrame("pr1_ds")
#
# NameError: name 'pd' is not defined
