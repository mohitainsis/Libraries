# %%
import numpy as np
import pandas as pd

# %%
data = pd.DataFrame(np.random.randint(0,1000,(30,5)))

# %%
data.head()
# Out:
#      0    1    2    3    4
# 0   82  519  968  852  107
# 1  429  592  492  182  289
# 2  740  297  804  540   50
# 3  620  519   73  396  583
# 4  774  643  447  523  124

# %%
data = {
    "Name": ["Aman", "Riya", "Karan", "Neha", "Rahul"],
    "Age": [23, 25, 24, 22, 26],
    "Salary": [50000, 60000, 55000, 52000, 65000],
    "Department": ["HR", "IT", "IT", "Finance", "HR"]
}

df = pd.DataFrame(data)
df.to_csv("pr1_ds")

# %%
df.loc[0,1]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\Thisi\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3811 try:
# -> 3812     return self._engine.get_loc(casted_key)
#    3813 except KeyError as err:
#
# File pandas/_libs/index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7096, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 1
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 df.loc[0,1]
#
# ...

# %%
df.loc[[0]]
# Out:
#    Name  Age  Salary Department
# 0  Aman   23   50000         HR

# %%
df.loc[["Salary",3]]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 df.loc[["Salary",3]]
#
# File c:\Users\Thisi\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\indexing.py:1192, in _LocationIndexer.__getitem__(self, key)
#    1190 maybe_callable = com.apply_if_callable(key, self.obj)
#    1191 maybe_callable = self._check_deprecated_callable_usage(key, maybe_callable)
# -> 1192 return self._getitem_axis(maybe_callable, axis=axis)
#
# File c:\Users\Thisi\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\indexing.py:1421, in _LocIndexer._getitem_axis(self, key, axis)
#    1418     if hasattr(key, "ndim") and key.ndim > 1:
#    1419         raise ValueError("Cannot index with multidimensional key")
# -> 1421     return self._getitem_iterable(key, axis=axis)
#    1423 # nested tuple slicing
# ...

# %%
df.loc["Salary",3]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\Thisi\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3811 try:
# -> 3812     return self._engine.get_loc(casted_key)
#    3813 except KeyError as err:
#
# File pandas/_libs/index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7096, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 3
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[21], line 1
# ...

# %%
df.loc[2,"Salary"]
# Out:
# np.int64(55000)

# %%
df[["Name","Salary"]]
# Out:
#     Name  Salary
# 0   Aman   50000
# 1   Riya   60000
# 2  Karan   55000
# 3   Neha   52000
# 4  Rahul   65000

# %%
df.loc[[1]]
# Out:
#    Name  Age  Salary Department
# 1  Riya   25   60000         IT

# %%
df.loc[1,"Salary"]
# Out:
# np.int64(60000)

# %%
df.loc[1:3]
# Out:
#     Name  Age  Salary Department
# 1   Riya   25   60000         IT
# 2  Karan   24   55000         IT
# 3   Neha   22   52000    Finance

# %%
df.loc["Riya","Age"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[32], line 1
# ----> 1 df.loc["Riya","Age"]
#
# File c:\Users\Thisi\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\indexing.py:1184, in _LocationIndexer.__getitem__(self, key)
#    1182     key = tuple(com.apply_if_callable(x, self.obj) for x in key)
#    1183     if self._is_scalar_access(key):
# -> 1184         return self.obj._get_value(*key, takeable=self._takeable)
#    1185     return self._getitem_tuple(key)
#    1186 else:
#    1187     # we by definition only have the 0th axis
#
# File c:\Users\Thisi\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\frame.py:4232, in DataFrame._get_value(self, index, col, takeable)
#    4226 engine = self.index._engine
#    4228 if not isinstance(self.index, MultiIndex):
# ...

# %%
df[df["Name"]=="Riya",df["Age"]]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File c:\Users\Thisi\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3811 try:
# -> 3812     return self._engine.get_loc(casted_key)
#    3813 except KeyError as err:
#
# File pandas/_libs/index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:173, in pandas._libs.index.IndexEngine.get_loc()
#
# TypeError: '(0    False
# 1     True
# 2    False
# 3    False
# 4    False
# Name: Name, dtype: bool, 0    23
# 1    25
# 2    24
# 3    22
# 4    26
# Name: Age, dtype: int64)' is an invalid key
#
# During handling of the above exception, another exception occurred:
#
# InvalidIndexError                         Traceback (most recent call last)
# Cell In[35], line 1
# ----> 1 df[df["Name"]=="Riya",df["Age"]]
#
# ...

# %%
df.loc[df["Name"]=="Riya"]
# Out:
#    Name  Age  Salary Department
# 1  Riya   25   60000         IT

# %%
df.iloc[4,2]
# Out:
# np.int64(65000)

# %%
df.iloc[1:4,[0,2]]
# Out:
#     Name  Salary
# 1   Riya   60000
# 2  Karan   55000
# 3   Neha   52000

# %%
df[df["Salary"]>55000]
# Out:
#     Name  Age  Salary Department
# 1   Riya   25   60000         IT
# 4  Rahul   26   65000         HR

# %%
df[df["Department"] == "IT"]
# Out:
#     Name  Age  Salary Department
# 1   Riya   25   60000         IT
# 2  Karan   24   55000         IT

# %%
df
# Out:
#     Name  Age  Salary Department
# 0   Aman   23   50000         HR
# 1   Riya   25   60000         IT
# 2  Karan   24   55000         IT
# 3   Neha   22   52000    Finance
# 4  Rahul   26   65000         HR

# %%
df.iloc[4,2]
# Out:
# np.int64(65000)

# %%
df.iloc[1:4,[0,2]]
# Out:
#     Name  Salary
# 1   Riya   60000
# 2  Karan   55000
# 3   Neha   52000

# %%
df.iloc[2,1]
# Out:
# np.int64(24)

# %%
df.iloc[0:3,[0]]
# Out:
#     Name
# 0   Aman
# 1   Riya
# 2  Karan

# %%
df.loc[df["Name"]=="Riya",["Age"]]
# Out:
#    Age
# 1   25

# %%
df.loc[df["Name"]=="Neha",["Salary"]]
# Out:
#    Salary
# 3   52000

# %%
df.iloc[1:4,[1,3]]
# Out:
#    Age Department
# 1   25         IT
# 2   24         IT
# 3   22    Finance

# %%
df.drop("Name",axis=1)
# Out:
#    Age  Salary Department
# 0   23   50000         HR
# 1   25   60000         IT
# 2   24   55000         IT
# 3   22   52000    Finance
# 4   26   65000         HR

# %%
df
# Out:
#     Name  Age  Salary Department
# 0   Aman   23   50000         HR
# 1   Riya   25   60000         IT
# 2  Karan   24   55000         IT
# 3   Neha   22   52000    Finance
# 4  Rahul   26   65000         HR

# %%
df.drop(["Name","Salary"],axis=1)
# Out:
#    Age Department
# 0   23         HR
# 1   25         IT
# 2   24         IT
# 3   22    Finance
# 4   26         HR

# %%
df.drop([1,2])
# Out:
#     Name  Age  Salary Department
# 0   Aman   23   50000         HR
# 3   Neha   22   52000    Finance
# 4  Rahul   26   65000         HR

# %%
df.drop("columns"="Age")
# Out:
#   Cell In[97], line 1
#     df.drop("columns"="Age")
#             ^
# SyntaxError: expression cannot contain assignment, perhaps you meant "=="?

# %%
df.drop(columns="Age")
# Out:
#     Name  Salary Department
# 0   Aman   50000         HR
# 1   Riya   60000         IT
# 2  Karan   55000         IT
# 3   Neha   52000    Finance
# 4  Rahul   65000         HR

# %%
df.drop(index=2,axis=1)
# Out:
#     Name  Age  Salary Department
# 0   Aman   23   50000         HR
# 1   Riya   25   60000         IT
# 3   Neha   22   52000    Finance
# 4  Rahul   26   65000         HR

# %%
df
# Out:
#     Name  Age  Salary Department
# 0   Aman   23   50000         HR
# 1   Riya   25   60000         IT
# 2  Karan   24   55000         IT
# 3   Neha   22   52000    Finance
# 4  Rahul   26   65000         HR

# %%
df.drop("Salary",axis=1)
# Out:
#     Name  Age Department
# 0   Aman   23         HR
# 1   Riya   25         IT
# 2  Karan   24         IT
# 3   Neha   22    Finance
# 4  Rahul   26         HR

# %%
df.drop(["Age","Department"],axis=1)
# Out:
#     Name  Salary
# 0   Aman   50000
# 1   Riya   60000
# 2  Karan   55000
# 3   Neha   52000
# 4  Rahul   65000

# %%
df.drop(4)
# Out:
#     Name  Age  Salary Department
# 0   Aman   23   50000         HR
# 1   Riya   25   60000         IT
# 2  Karan   24   55000         IT
# 3   Neha   22   52000    Finance

# %%
df.drop([1:4])
# Out:
#   Cell In[107], line 1
#     df.drop([1:4])
#               ^
# SyntaxError: invalid syntax

# %%
df.drop("Age",axis=1)
# Out:
#     Name  Salary Department
# 0   Aman   50000         HR
# 1   Riya   60000         IT
# 2  Karan   55000         IT
# 3   Neha   52000    Finance
# 4  Rahul   65000         HR

# %%
df.drop([1,3])
# Out:
#     Name  Age  Salary Department
# 0   Aman   23   50000         HR
# 2  Karan   24   55000         IT
# 4  Rahul   26   65000         HR

# %%
df.drop(df.index[1:4],axis=0)
# Out:
#     Name  Age  Salary Department
# 0   Aman   23   50000         HR
# 4  Rahul   26   65000         HR

# %%
df.reset_index()
# Out:
#    index   Name  Age  Salary Department
# 0      0   Aman   23   50000         HR
# 1      1   Riya   25   60000         IT
# 2      2  Karan   24   55000         IT
# 3      3   Neha   22   52000    Finance
# 4      4  Rahul   26   65000         HR

# %%
df.drop("index")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[115], line 1
# ----> 1 df.drop("index")
#
# File c:\Users\Thisi\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\frame.py:5603, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5455 def drop(
#    5456     self,
#    5457     labels: IndexLabel | None = None,
#    (...)   5464     errors: IgnoreRaise = "raise",
#    5465 ) -> DataFrame | None:
#    5466     """
#    5467     Drop specified labels from rows or columns.
#    5468
#    (...)   5601             weight  1.0     0.8
#    5602     """
# -> 5603     return super().drop(
#    5604         labels=labels,
#    5605         axis=axis,
#    5606         index=index,
#    5607         columns=columns,
#    5608         level=level,
#    5609         inplace=inplace,
#    5610         errors=errors,
#    5611     )
# ...

# %%
df.drop(index=True,inplace="True")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[116], line 1
# ----> 1 df.drop(index=True,inplace="True")
#
# File c:\Users\Thisi\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\frame.py:5603, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5455 def drop(
#    5456     self,
#    5457     labels: IndexLabel | None = None,
#    (...)   5464     errors: IgnoreRaise = "raise",
#    5465 ) -> DataFrame | None:
#    5466     """
#    5467     Drop specified labels from rows or columns.
#    5468
#    (...)   5601             weight  1.0     0.8
#    5602     """
# -> 5603     return super().drop(
#    5604         labels=labels,
#    5605         axis=axis,
#    5606         index=index,
#    5607         columns=columns,
#    5608         level=level,
#    5609         inplace=inplace,
# ...

# %%
df.reset_index(drop=True,inplace=True)

# %%
df
# Out:
#     Name  Age  Salary Department
# 0   Aman   23   50000         HR
# 1   Riya   25   60000         IT
# 2  Karan   24   55000         IT
# 3   Neha   22   52000    Finance
# 4  Rahul   26   65000         HR

# %%
df.loc[:,["Name","Age"]]=56

# %%
data = pd.read_csv("pr1_ds")

# %%
data
# Out:
#    Unnamed: 0   Name  Age  Salary Department
# 0           0   Aman   23   50000         HR
# 1           1   Riya   25   60000         IT
# 2           2  Karan   24   55000         IT
# 3           3   Neha   22   52000    Finance
# 4           4  Rahul   26   65000         HR

# %%
data.drop(1)
# Out:
#    Unnamed: 0   Name  Age  Salary Department
# 0           0   Aman   23   50000         HR
# 2           2  Karan   24   55000         IT
# 3           3   Neha   22   52000    Finance
# 4           4  Rahul   26   65000         HR

# %%
data
# Out:
#    Unnamed: 0   Name  Age  Salary Department
# 0           0   Aman   23   50000         HR
# 1           1   Riya   25   60000         IT
# 2           2  Karan   24   55000         IT
# 3           3   Neha   22   52000    Finance
# 4           4  Rahul   26   65000         HR

# %%
data.columns[1]
# Out:
# 'Name'

# %%
data
# Out:
#    Unnamed: 0   Name  Age  Salary Department
# 0           0   Aman   23   50000         HR
# 1           1   Riya   25   60000         IT
# 2           2  Karan   24   55000         IT
# 3           3   Neha   22   52000    Finance
# 4           4  Rahul   26   65000         HR

# %%
data.drop(data.columns[1],axis= 1)
# Out:
#    Unnamed: 0  Age  Salary Department
# 0           0   23   50000         HR
# 1           1   25   60000         IT
# 2           2   24   55000         IT
# 3           3   22   52000    Finance
# 4           4   26   65000         HR

# %%
data
# Out:
#    Unnamed: 0   Name  Age  Salary Department
# 0           0   Aman   23   50000         HR
# 1           1   Riya   25   60000         IT
# 2           2  Karan   24   55000         IT
# 3           3   Neha   22   52000    Finance
# 4           4  Rahul   26   65000         HR

# %%
data.drop(data.columns[0],axis=1,inplace= True)

# %%
data
# Out:
#     Name  Age  Salary Department
# 0   Aman   23   50000         HR
# 1   Riya   25   60000         IT
# 2  Karan   24   55000         IT
# 3   Neha   22   52000    Finance
# 4  Rahul   26   65000         HR
