# %%
import pandas as pd

# %%
data = {
    "Name": ["A","B","C"],
    "Sales":[100,200,150]
}

df = pd.DataFrame(data)
df
# Out:
#   Name  Sales
# 0    A    100
# 1    B    200
# 2    C    150

# %%
df.to_csv("friends")

# %%
data2 = {
    "names":["Mohan","Rohan","Johan","Sohan"],
    "Salary":[90000,80000,70000,90]
}
table = pd.DataFrame(data2)
table
# Out:
#    names  Salary
# 0  Mohan   90000
# 1  Rohan   80000
# 2  Johan   70000
# 3  Sohan      90

# %%
table.to_csv('file1',index=False)

# %%
table.describe()
# Out:
#              Salary
# count      4.000000
# mean   60022.500000
# std    40780.739224
# min       90.000000
# 25%    52522.500000
# 50%    75000.000000
# 75%    82500.000000
# max    90000.000000

# %%
table.name("calories")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_9232\1556505996.py in ?()
# ----> 1 table.name("calories")
#
# c:\Users\Thisi\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    6317             and name not in self._accessors
#    6318             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6319         ):
#    6320             return self[name]
# -> 6321         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'name'

# %%
data2.name=("calories")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 data2.name=("calories")
#
# AttributeError: 'dict' object has no attribute 'name' and no __dict__ for setting new attributes

# %%
data2.name = "calories"
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 data2.name = "calories"
#
# AttributeError: 'dict' object has no attribute 'name' and no __dict__ for setting new attributes

# %%
str = ([1,2,3,5,6,7])
new = pd.Series(str)
new
# Out:
# 0    1
# 1    2
# 2    3
# 3    5
# 4    6
# 5    7
# dtype: int64

# %%
str.name = "numbers"
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 str.name = "numbers"
#
# AttributeError: 'list' object has no attribute 'name' and no __dict__ for setting new attributes

# %%
data = {
     "Customer_ID": [101,102,103,104,105,106,107,108],
    "Customer_Name": ["Mohan","Rohan","Sohan","Aman","Karan","Neha","Priya","Rahul"],
    "City": ["Delhi","Mumbai","Delhi","Bangalore","Mumbai","Delhi","Bangalore","Mumbai"],
    "Product": ["Laptop","Phone","Tablet","Laptop","Phone","Tablet","Laptop","Phone"],
    "Sales": [55000,20000,15000,60000,22000,14000,58000,21000],
    "Profit": [8000,3000,2000,9000,3200,1800,8500,3100],
    "Quantity": [2,5,3,1,4,2,2,6],
    "Order_Date": [
        "2024-01-10","2024-01-12","2024-01-15","2024-02-01",
        "2024-02-05","2024-02-10","2024-03-02","2024-03-08"
    ]
}

df = pd.DataFrame(data)
df
# Out:
#    Customer_ID Customer_Name       City Product  Sales  Profit  Quantity  \
# 0          101         Mohan      Delhi  Laptop  55000    8000         2
# 1          102         Rohan     Mumbai   Phone  20000    3000         5
# 2          103         Sohan      Delhi  Tablet  15000    2000         3
# 3          104          Aman  Bangalore  Laptop  60000    9000         1
# 4          105         Karan     Mumbai   Phone  22000    3200         4
# 5          106          Neha      Delhi  Tablet  14000    1800         2
# 6          107         Priya  Bangalore  Laptop  58000    8500         2
# 7          108         Rahul     Mumbai   Phone  21000    3100         6
#
#    Order_Date
# 0  2024-01-10
# 1  2024-01-12
# 2  2024-01-15
# 3  2024-02-01
# 4  2024-02-05
# 5  2024-02-10
# 6  2024-03-02
# 7  2024-03-08

# %%
df.head()
df.info()
df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8 entries, 0 to 7
# Data columns (total 8 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Customer_ID    8 non-null      int64
#  1   Customer_Name  8 non-null      object
#  2   City           8 non-null      object
#  3   Product        8 non-null      object
#  4   Sales          8 non-null      int64
#  5   Profit         8 non-null      int64
#  6   Quantity       8 non-null      int64
#  7   Order_Date     8 non-null      object
# dtypes: int64(4), object(4)
# memory usage: 644.0+ bytes
#        Customer_ID         Sales       Profit  Quantity
# count      8.00000      8.000000     8.000000  8.000000
# mean     104.50000  33125.000000  4825.000000  3.125000
# std        2.44949  20552.632782  3095.965116  1.726888
# min      101.00000  14000.000000  1800.000000  1.000000
# 25%      102.75000  18750.000000  2750.000000  2.000000
# ...

# %%
df["profit_margin"] = df["Sales"] / df["Profit"]

# %%
df
# Out:
#    Customer_ID Customer_Name       City Product  Sales  Profit  Quantity  \
# 0          101         Mohan      Delhi  Laptop  55000    8000         2
# 1          102         Rohan     Mumbai   Phone  20000    3000         5
# 2          103         Sohan      Delhi  Tablet  15000    2000         3
# 3          104          Aman  Bangalore  Laptop  60000    9000         1
# 4          105         Karan     Mumbai   Phone  22000    3200         4
# 5          106          Neha      Delhi  Tablet  14000    1800         2
# 6          107         Priya  Bangalore  Laptop  58000    8500         2
# 7          108         Rahul     Mumbai   Phone  21000    3100         6
#
#    Order_Date  profit_margin
# 0  2024-01-10       6.875000
# 1  2024-01-12       6.666667
# 2  2024-01-15       7.500000
# 3  2024-02-01       6.666667
# 4  2024-02-05       6.875000
# 5  2024-02-10       7.777778
# 6  2024-03-02       6.823529
# 7  2024-03-08       6.774194

# %%
df.rename(columns={"Sales":"Revenue"})
# Out:
#    Customer_ID Customer_Name       City Product  Revenue  Profit  Quantity  \
# 0          101         Mohan      Delhi  Laptop    55000    8000         2
# 1          102         Rohan     Mumbai   Phone    20000    3000         5
# 2          103         Sohan      Delhi  Tablet    15000    2000         3
# 3          104          Aman  Bangalore  Laptop    60000    9000         1
# 4          105         Karan     Mumbai   Phone    22000    3200         4
# 5          106          Neha      Delhi  Tablet    14000    1800         2
# 6          107         Priya  Bangalore  Laptop    58000    8500         2
# 7          108         Rahul     Mumbai   Phone    21000    3100         6
#
#    Order_Date  profit_margin
# 0  2024-01-10       6.875000
# 1  2024-01-12       6.666667
# 2  2024-01-15       7.500000
# 3  2024-02-01       6.666667
# 4  2024-02-05       6.875000
# 5  2024-02-10       7.777778
# 6  2024-03-02       6.823529
# 7  2024-03-08       6.774194

# %%
df
# Out:
#    Customer_ID Customer_Name       City Product  Sales  Profit  Quantity  \
# 0          101         Mohan      Delhi  Laptop  55000    8000         2
# 1          102         Rohan     Mumbai   Phone  20000    3000         5
# 2          103         Sohan      Delhi  Tablet  15000    2000         3
# 3          104          Aman  Bangalore  Laptop  60000    9000         1
# 4          105         Karan     Mumbai   Phone  22000    3200         4
# 5          106          Neha      Delhi  Tablet  14000    1800         2
# 6          107         Priya  Bangalore  Laptop  58000    8500         2
# 7          108         Rahul     Mumbai   Phone  21000    3100         6
#
#    Order_Date  profit_margin
# 0  2024-01-10       6.875000
# 1  2024-01-12       6.666667
# 2  2024-01-15       7.500000
# 3  2024-02-01       6.666667
# 4  2024-02-05       6.875000
# 5  2024-02-10       7.777778
# 6  2024-03-02       6.823529
# 7  2024-03-08       6.774194

# %%
df.rename(columns={"Sales":"Revenue"},inplace=True)

# %%
df
# Out:
#    Customer_ID Customer_Name       City Product  Revenue  Profit  Quantity  \
# 0          101         Mohan      Delhi  Laptop    55000    8000         2
# 1          102         Rohan     Mumbai   Phone    20000    3000         5
# 2          103         Sohan      Delhi  Tablet    15000    2000         3
# 3          104          Aman  Bangalore  Laptop    60000    9000         1
# 4          105         Karan     Mumbai   Phone    22000    3200         4
# 5          106          Neha      Delhi  Tablet    14000    1800         2
# 6          107         Priya  Bangalore  Laptop    58000    8500         2
# 7          108         Rahul     Mumbai   Phone    21000    3100         6
#
#    Order_Date  profit_margin
# 0  2024-01-10       6.875000
# 1  2024-01-12       6.666667
# 2  2024-01-15       7.500000
# 3  2024-02-01       6.666667
# 4  2024-02-05       6.875000
# 5  2024-02-10       7.777778
# 6  2024-03-02       6.823529
# 7  2024-03-08       6.774194

# %%
df.describe(
)
# Out:
#        Customer_ID       Revenue       Profit  Quantity  profit_margin
# count      8.00000      8.000000     8.000000  8.000000       8.000000
# mean     104.50000  33125.000000  4825.000000  3.125000       6.994854
# std        2.44949  20552.632782  3095.965116  1.726888       0.412368
# min      101.00000  14000.000000  1800.000000  1.000000       6.666667
# 25%      102.75000  18750.000000  2750.000000  2.000000       6.747312
# 50%      104.50000  21500.000000  3150.000000  2.500000       6.849265
# 75%      106.25000  55750.000000  8125.000000  4.250000       7.031250
# max      108.00000  60000.000000  9000.000000  6.000000       7.777778

# %%
df["new"] = df["sales"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\Thisi\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3811 try:
# -> 3812     return self._engine.get_loc(casted_key)
#    3813 except KeyError as err:
#
# File pandas/_libs/index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7096, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'sales'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[20], line 1
# ...

# %%
# Out:
#    Customer_ID Customer_Name       City Product  Revenue  Profit  Quantity  \
# 0          101         Mohan      Delhi  Laptop    55000    8000         2
# 1          102         Rohan     Mumbai   Phone    20000    3000         5
# 2          103         Sohan      Delhi  Tablet    15000    2000         3
# 3          104          Aman  Bangalore  Laptop    60000    9000         1
# 4          105         Karan     Mumbai   Phone    22000    3200         4
# 5          106          Neha      Delhi  Tablet    14000    1800         2
# 6          107         Priya  Bangalore  Laptop    58000    8500         2
# 7          108         Rahul     Mumbai   Phone    21000    3100         6
#
#    Order_Date  profit_margin
# 0  2024-01-10       6.875000
# 1  2024-01-12       6.666667
# 2  2024-01-15       7.500000
# 3  2024-02-01       6.666667
# 4  2024-02-05       6.875000
# 5  2024-02-10       7.777778
# 6  2024-03-02       6.823529
# 7  2024-03-08       6.774194

# %%
df["new"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\Thisi\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3811 try:
# -> 3812     return self._engine.get_loc(casted_key)
#    3813 except KeyError as err:
#
# File pandas/_libs/index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7096, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'new'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 df["new"]
#
# ...

# %%
data = {
    "Customer": ["Mohan","Rohan","Sohan","Aman","Neha","Priya","Karan","Rahul"],
    "City": ["Delhi","Mumbai","Delhi","Bangalore","Mumbai","Delhi","Bangalore","Mumbai"],
    "Product": ["Laptop","Phone","Tablet","Laptop","Phone","Tablet","Laptop","Phone"],
    "Sales": [55000,20000,15000,60000,22000,14000,58000,21000],
    "Profit": [8000,3000,2000,9000,3200,1800,8500,None],
    "Quantity": [2,5,3,1,4,2,2,6]
}
df = pd.DataFrame[data]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[72], line 9
#       1 data = {
#       2     "Customer": ["Mohan","Rohan","Sohan","Aman","Neha","Priya","Karan","Rahul"],
#       3     "City": ["Delhi","Mumbai","Delhi","Bangalore","Mumbai","Delhi","Bangalore","Mumbai"],
#    (...)      7     "Quantity": [2,5,3,1,4,2,2,6]
#       8 }
# ----> 9 df = pd.DataFrame[data]
#
# TypeError: type 'DataFrame' is not subscriptable

# %%
dd = pd.DataFrame(data)

# %%
dd
# Out:
#   Customer       City Product  Sales  Profit  Quantity
# 0    Mohan      Delhi  Laptop  55000  8000.0         2
# 1    Rohan     Mumbai   Phone  20000  3000.0         5
# 2    Sohan      Delhi  Tablet  15000  2000.0         3
# 3     Aman  Bangalore  Laptop  60000  9000.0         1
# 4     Neha     Mumbai   Phone  22000  3200.0         4
# 5    Priya      Delhi  Tablet  14000  1800.0         2
# 6    Karan  Bangalore  Laptop  58000  8500.0         2
# 7    Rahul     Mumbai   Phone  21000     NaN         6

# %%
dd.head(5)
# Out:
#   Customer       City Product  Sales  Profit  Quantity
# 0    Mohan      Delhi  Laptop  55000    8000         2
# 1    Rohan     Mumbai   Phone  20000    3000         5
# 2    Sohan      Delhi  Tablet  15000    2000         3
# 3     Aman  Bangalore  Laptop  60000    9000         1
# 4     Neha     Mumbai   Phone  22000    3200         4

# %%
dd.info
# Out:
# <bound method DataFrame.info of   Customer       City Product  Sales  Profit  Quantity
# 0    Mohan      Delhi  Laptop  55000    8000         2
# 1    Rohan     Mumbai   Phone  20000    3000         5
# 2    Sohan      Delhi  Tablet  15000    2000         3
# 3     Aman  Bangalore  Laptop  60000    9000         1
# 4     Neha     Mumbai   Phone  22000    3200         4
# 5    Priya      Delhi  Tablet  14000    1800         2
# 6    Karan  Bangalore  Laptop  58000    8500         2
# 7    Rahul     Mumbai   Phone  21000    3100         6>

# %%
dd["Sales"]
# Out:
# 0    55000
# 1    20000
# 2    15000
# 3    60000
# 4    22000
# 5    14000
# 6    58000
# 7    21000
# Name: Sales, dtype: int64

# %%
dd[["Sales","Profit"]]
# Out:
#    Sales  Profit
# 0  55000    8000
# 1  20000    3000
# 2  15000    2000
# 3  60000    9000
# 4  22000    3200
# 5  14000    1800
# 6  58000    8500
# 7  21000    3100

# %%
dd["Sales">30000]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[31], line 1
# ----> 1 dd["Sales">30000]
#
# TypeError: '>' not supported between instances of 'str' and 'int'

# %%
dd[dd["Sales"]>30000]
# Out:
#   Customer       City Product  Sales  Profit  Quantity
# 0    Mohan      Delhi  Laptop  55000    8000         2
# 3     Aman  Bangalore  Laptop  60000    9000         1
# 6    Karan  Bangalore  Laptop  58000    8500         2

# %%
dd[dd["City"] =="Delhi"]
# Out:
#   Customer   City Product  Sales  Profit  Quantity
# 0    Mohan  Delhi  Laptop  55000    8000         2
# 2    Sohan  Delhi  Tablet  15000    2000         3
# 5    Priya  Delhi  Tablet  14000    1800         2

# %%
dd[dd["Profit"]>5000]
# Out:
#   Customer       City Product  Sales  Profit  Quantity
# 0    Mohan      Delhi  Laptop  55000    8000         2
# 3     Aman  Bangalore  Laptop  60000    9000         1
# 6    Karan  Bangalore  Laptop  58000    8500         2

# %%
dd.sort_values(by="Sales",ascending=True)
# Out:
#   Customer       City Product  Sales  Profit  Quantity
# 5    Priya      Delhi  Tablet  14000    1800         2
# 2    Sohan      Delhi  Tablet  15000    2000         3
# 1    Rohan     Mumbai   Phone  20000    3000         5
# 7    Rahul     Mumbai   Phone  21000    3100         6
# 4     Neha     Mumbai   Phone  22000    3200         4
# 0    Mohan      Delhi  Laptop  55000    8000         2
# 6    Karan  Bangalore  Laptop  58000    8500         2
# 3     Aman  Bangalore  Laptop  60000    9000         1

# %%
dd.sort_values(by="Sales",ascending=False)
# Out:
#   Customer       City Product  Sales  Profit  Quantity
# 3     Aman  Bangalore  Laptop  60000    9000         1
# 6    Karan  Bangalore  Laptop  58000    8500         2
# 0    Mohan      Delhi  Laptop  55000    8000         2
# 4     Neha     Mumbai   Phone  22000    3200         4
# 7    Rahul     Mumbai   Phone  21000    3100         6
# 1    Rohan     Mumbai   Phone  20000    3000         5
# 2    Sohan      Delhi  Tablet  15000    2000         3
# 5    Priya      Delhi  Tablet  14000    1800         2

# %%
dd["Profit_margin"] = dd["Profit"]/dd["Sales"]

# %%
dd
# Out:
#   Customer       City Product  Sales  Profit  Quantity  Profit_margin
# 0    Mohan      Delhi  Laptop  55000    8000         2       0.145455
# 1    Rohan     Mumbai   Phone  20000    3000         5       0.150000
# 2    Sohan      Delhi  Tablet  15000    2000         3       0.133333
# 3     Aman  Bangalore  Laptop  60000    9000         1       0.150000
# 4     Neha     Mumbai   Phone  22000    3200         4       0.145455
# 5    Priya      Delhi  Tablet  14000    1800         2       0.128571
# 6    Karan  Bangalore  Laptop  58000    8500         2       0.146552
# 7    Rahul     Mumbai   Phone  21000    3100         6       0.147619

# %%
dd.rename(columns={"Customer":"Customer_name",
          "Sales":"Revenue",
          "Profit":"Net_Profit"},inplace=True)

# %%
dd[dd["Revenue"]>25000]
# Out:
#   Customer_name       City Product  Revenue  Net_Profit  Quantity  \
# 0         Mohan      Delhi  Laptop    55000        8000         2
# 3          Aman  Bangalore  Laptop    60000        9000         1
# 6         Karan  Bangalore  Laptop    58000        8500         2
#
#    Profit_margin
# 0       0.145455
# 3       0.150000
# 6       0.146552

# %%
dd[(dd["Revenue"]>20000) & (dd["City"]=="Delhi")]
# Out:
#   Customer_name   City Product  Revenue  Net_Profit  Quantity  Profit_margin
# 0         Mohan  Delhi  Laptop    55000        8000         2       0.145455

# %%
dd[(dd["Revenue"]>20000) & (dd["City"] == "Bangalore")]
# Out:
#   Customer_name       City Product  Revenue  Net_Profit  Quantity  \
# 3          Aman  Bangalore  Laptop    60000        9000         1
# 6         Karan  Bangalore  Laptop    58000        8500         2
#
#    Profit_margin
# 3       0.150000
# 6       0.146552

# %%
dd["City"].value_counts()
# Out:
# City
# Delhi        3
# Mumbai       3
# Bangalore    2
# Name: count, dtype: int64

# %%
dd.isnull().sum()
# Out:
# Customer    0
# City        0
# Product     0
# Sales       0
# Profit      1
# Quantity    0
# dtype: int64

# %%
dd.dropna(how="any")
# Out:
#   Customer       City Product  Sales  Profit  Quantity
# 0    Mohan      Delhi  Laptop  55000  8000.0         2
# 1    Rohan     Mumbai   Phone  20000  3000.0         5
# 2    Sohan      Delhi  Tablet  15000  2000.0         3
# 3     Aman  Bangalore  Laptop  60000  9000.0         1
# 4     Neha     Mumbai   Phone  22000  3200.0         4
# 5    Priya      Delhi  Tablet  14000  1800.0         2
# 6    Karan  Bangalore  Laptop  58000  8500.0         2

# %%
dd.isnull().sum()
# Out:
# Customer    0
# City        0
# Product     0
# Sales       0
# Profit      1
# Quantity    0
# dtype: int64

# %%
dd.dropna(how="all")
# Out:
#   Customer       City Product  Sales  Profit  Quantity
# 0    Mohan      Delhi  Laptop  55000  8000.0         2
# 1    Rohan     Mumbai   Phone  20000  3000.0         5
# 2    Sohan      Delhi  Tablet  15000  2000.0         3
# 3     Aman  Bangalore  Laptop  60000  9000.0         1
# 4     Neha     Mumbai   Phone  22000  3200.0         4
# 5    Priya      Delhi  Tablet  14000  1800.0         2
# 6    Karan  Bangalore  Laptop  58000  8500.0         2
# 7    Rahul     Mumbai   Phone  21000     NaN         6

# %%
dd
# Out:
#   Customer       City Product  Sales  Profit  Quantity
# 0    Mohan      Delhi  Laptop  55000  8000.0         2
# 1    Rohan     Mumbai   Phone  20000  3000.0         5
# 2    Sohan      Delhi  Tablet  15000  2000.0         3
# 3     Aman  Bangalore  Laptop  60000  9000.0         1
# 4     Neha     Mumbai   Phone  22000  3200.0         4
# 5    Priya      Delhi  Tablet  14000  1800.0         2
# 6    Karan  Bangalore  Laptop  58000  8500.0         2
# 7    Rahul     Mumbai   Phone  21000     NaN         6

# %%
dd.to_csv()
# Out:
# ',Customer,City,Product,Sales,Profit,Quantity\r\n0,Mohan,Delhi,Laptop,55000,8000.0,2\r\n1,Rohan,Mumbai,Phone,20000,3000.0,5\r\n2,Sohan,Delhi,Tablet,15000,2000.0,3\r\n3,Aman,Bangalore,Laptop,60000,9000.0,1\r\n4,Neha,Mumbai,Phone,22000,3200.0,4\r\n5,Priya,Delhi,Tablet,14000,1800.0,2\r\n6,Karan,Bangalore,Laptop,58000,8500.0,2\r\n7,Rahul,Mumbai,Phone,21000,,6\r\n'

# %%
dd.to_csv
# Out:
# <bound method NDFrame.to_csv of   Customer       City Product  Sales  Profit  Quantity
# 0    Mohan      Delhi  Laptop  55000  8000.0         2
# 1    Rohan     Mumbai   Phone  20000  3000.0         5
# 2    Sohan      Delhi  Tablet  15000  2000.0         3
# 3     Aman  Bangalore  Laptop  60000  9000.0         1
# 4     Neha     Mumbai   Phone  22000  3200.0         4
# 5    Priya      Delhi  Tablet  14000  1800.0         2
# 6    Karan  Bangalore  Laptop  58000  8500.0         2
# 7    Rahul     Mumbai   Phone  21000     NaN         6>

# %%
dd.to_csv("pr_data")
