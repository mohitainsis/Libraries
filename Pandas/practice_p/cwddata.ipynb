# %%
import numpy as np
import pandas as pd

# %%
data = pd.DataFrame(np.random.rand(36))

# %%
data.head()
# Out:
#           0
# 0  0.664745
# 1  0.985351
# 2  0.143848
# 3  0.322106
# 4  0.818563

# %%
data = pd.DataFrame(np.random.rand(10,4))

# %%
data[0][1] = "harry"
# Out:
# C:\Users\Thisi\AppData\Local\Temp\ipykernel_13800\2537421035.py:1: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data[0][1] = "harry"
# ...

# %%
data
# Out:
#           0         1         2         3
# 0  0.166017  0.645033  0.423597  0.413536
# 1  0.891948  0.590614  0.216473  0.748107
# 2  0.269600  0.486330  0.163721  0.931438
# 3  0.790374  0.928897  0.394122  0.391876
# 4  0.935842  0.775874  0.118925  0.143376
# 5  0.804405  0.481620  0.250906  0.464788
# 6  0.626006  0.523925  0.664943  0.208023
# 7  0.747168  0.162307  0.590672  0.172468
# 8  0.741437  0.044433  0.702413  0.600592
# 9  0.843314  0.384615  0.658468  0.120444

# %%
data.index['first','Second']
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 data.index['first','Second']
#
# File c:\Users\Thisi\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\indexes\range.py:1030, in RangeIndex.__getitem__(self, key)
#    1023 elif is_scalar(key):
#    1024     raise IndexError(
#    1025         "only integers, slices (`:`), "
#    1026         "ellipsis (`...`), numpy.newaxis (`None`) "
#    1027         "and integer or boolean "
#    1028         "arrays are valid indices"
#    1029     )
# -> 1030 return super().__getitem__(key)
#
# File c:\Users\Thisi\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\indexes\base.py:5428, in Index.__getitem__(self, key)
#    5419         if len(key) == 0 and len(key) != len(self):
#    5420             warnings.warn(
# ...

# %%
data.sum(axis=0)
# Out:
# 0    6.816112
# 1    5.023647
# 2    4.184240
# 3    4.194649
# dtype: float64

# %%
# Out:
#           0         1         2         3
# 0  0.166017  0.645033  0.423597  0.413536
# 1  0.891948  0.590614  0.216473  0.748107
# 2  0.269600  0.486330  0.163721  0.931438
# 3  0.790374  0.928897  0.394122  0.391876
# 4  0.935842  0.775874  0.118925  0.143376
# 5  0.804405  0.481620  0.250906  0.464788
# 6  0.626006  0.523925  0.664943  0.208023
# 7  0.747168  0.162307  0.590672  0.172468
# 8  0.741437  0.044433  0.702413  0.600592
# 9  0.843314  0.384615  0.658468  0.120444

# %%
data.iloc[0]
# Out:
# 0    0.166017
# 1    0.645033
# 2    0.423597
# 3    0.413536
# Name: 0, dtype: float64

# %%
data.iloc[1]
# Out:
# 0    0.891948
# 1    0.590614
# 2    0.216473
# 3    0.748107
# Name: 1, dtype: float64

# %%
data[0]
# Out:
# 0    0.166017
# 1    0.891948
# 2    0.269600
# 3    0.790374
# 4    0.935842
# 5    0.804405
# 6    0.626006
# 7    0.747168
# 8    0.741437
# 9    0.843314
# Name: 0, dtype: float64

# %%
data.iloc[0,1]
# Out:
# np.float64(0.6450330481507865)

# %%
data
# Out:
#           0         1         2         3
# 0  0.166017  0.645033  0.423597  0.413536
# 1  0.891948  0.590614  0.216473  0.748107
# 2  0.269600  0.486330  0.163721  0.931438
# 3  0.790374  0.928897  0.394122  0.391876
# 4  0.935842  0.775874  0.118925  0.143376
# 5  0.804405  0.481620  0.250906  0.464788
# 6  0.626006  0.523925  0.664943  0.208023
# 7  0.747168  0.162307  0.590672  0.172468
# 8  0.741437  0.044433  0.702413  0.600592
# 9  0.843314  0.384615  0.658468  0.120444

# %%
data.iloc[0:2]
# Out:
#           0         1         2         3
# 0  0.166017  0.645033  0.423597  0.413536
# 1  0.891948  0.590614  0.216473  0.748107

# %%
data.iloc[0:2,0:2]
# Out:
#           0         1
# 0  0.166017  0.645033
# 1  0.891948  0.590614

# %%
data = pd.read_csv("pr_data")

# %%
data
# Out:
#    Unnamed: 0 Customer       City Product  Sales  Profit  Quantity
# 0           0    Mohan      Delhi  Laptop  55000  8000.0         2
# 1           1    Rohan     Mumbai   Phone  20000  3000.0         5
# 2           2    Sohan      Delhi  Tablet  15000  2000.0         3
# 3           3     Aman  Bangalore  Laptop  60000  9000.0         1
# 4           4     Neha     Mumbai   Phone  22000  3200.0         4
# 5           5    Priya      Delhi  Tablet  14000  1800.0         2
# 6           6    Karan  Bangalore  Laptop  58000  8500.0         2
# 7           7    Rahul     Mumbai   Phone  21000     NaN         6

# %%
data = pd.DataFrame(np.random.randint(0,100,(10,4)))

# %%
data
# Out:
#     0   1   2   3
# 0  30  91  43  95
# 1  50  19  86  92
# 2  47  70  52  29
# 3  25  43  14  65
# 4  40  24  73  58
# 5  15  77  85  76
# 6  64  23  60  89
# 7  96  44  15  95
# 8  72  51   6  64
# 9  72  58  46  29

# %%
data.loc[1,3]
# Out:
# np.int32(92)

# %%
# Out:
#     0   1   2   3
# 0  30  91  43  95
# 1  50  19  86  92
# 2  47  70  52  29
# 3  25  43  14  65
# 4  40  24  73  58

# %%
data
# Out:
#     0   1   2   3
# 0  30  91  43  95
# 1  50  19  86  92
# 2  47  70  52  29
# 3  25  43  14  65
# 4  40  24  73  58
# 5  15  77  85  76
# 6  64  23  60  89
# 7  96  44  15  95
# 8  72  51   6  64
# 9  72  58  46  29

# %%
data
# Out:
#    Unnamed: 0 Customer       City Product  Sales  Profit  Quantity
# 0           0    Mohan      Delhi  Laptop  55000  8000.0         2
# 1           1    Rohan     Mumbai   Phone  20000  3000.0         5
# 2           2    Sohan      Delhi  Tablet  15000  2000.0         3
# 3           3     Aman  Bangalore  Laptop  60000  9000.0         1
# 4           4     Neha     Mumbai   Phone  22000  3200.0         4
# 5           5    Priya      Delhi  Tablet  14000  1800.0         2
# 6           6    Karan  Bangalore  Laptop  58000  8500.0         2
# 7           7    Rahul     Mumbai   Phone  21000     NaN         6

# %%
data.drop(0,axis=1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[58], line 1
# ----> 1 data.drop(0,axis=1)
#
# File c:\Users\Thisi\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\frame.py:5603, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5455 def drop(
#    5456     self,
#    5457     labels: IndexLabel | None = None,
#    (...)   5464     errors: IgnoreRaise = "raise",
#    5465 ) -> DataFrame | None:
#    5466     """
#    5467     Drop specified labels from rows or columns.
#    5468
#    (...)   5601             weight  1.0     0.8
#    5602     """
# -> 5603     return super().drop(
#    5604         labels=labels,
#    5605         axis=axis,
#    5606         index=index,
#    5607         columns=columns,
#    5608         level=level,
#    5609         inplace=inplace,
#    5610         errors=errors,
# ...

# %%
data.drop([0],axis=1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[59], line 1
# ----> 1 data.drop([0],axis=1)
#
# File c:\Users\Thisi\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\frame.py:5603, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5455 def drop(
#    5456     self,
#    5457     labels: IndexLabel | None = None,
#    (...)   5464     errors: IgnoreRaise = "raise",
#    5465 ) -> DataFrame | None:
#    5466     """
#    5467     Drop specified labels from rows or columns.
#    5468
#    (...)   5601             weight  1.0     0.8
#    5602     """
# -> 5603     return super().drop(
#    5604         labels=labels,
#    5605         axis=axis,
#    5606         index=index,
#    5607         columns=columns,
#    5608         level=level,
#    5609         inplace=inplace,
#    5610         errors=errors,
# ...

# %%
data = pd.DataFrame(np.random.randint(0,1000,(20,7)))

# %%
data
# Out:
#       0    1    2    3    4    5    6
# 0   265  340  975  366  316  657  494
# 1   939  925  579  690  819  719  525
# 2   203   34  695  414  793  131  461
# 3   631  960   43  269  173   92  313
# 4   149   71  545  280  406  195  197
# 5   355  844   12  157  880   15  166
# 6   758  502  631  724  314  151  646
# 7   366  933  731  798  585  100    5
# 8   462  218  439  168  170  346  705
# 9   750  719  586  126  113  171  163
# 10  454  378  457  586  985  129   58
# 11  457  967  640  682  694  110  428
# 12   61  175  693   26  804  808  462
# 13  923  881  169  896   82  240  185
# 14  561  860  528  487  929  562  142
# 15  935  699  874  244   49  534   49
# 16  677  916  738  111  269  467  582
# 17  122  897  239  565  642  887  242
# 18  405  400  209  802  771  347  171
# 19  936  160  342  728  316  410  557

# %%
data[0:4]>500
# Out:
#        0      1      2      3      4      5      6
# 0  False  False   True  False  False   True  False
# 1   True   True   True   True   True   True   True
# 2  False  False   True  False   True  False  False
# 3   True   True  False  False  False  False  False

# %%
data[0]>500
# Out:
# 0     False
# 1      True
# 2     False
# 3      True
# 4     False
# 5     False
# 6      True
# 7     False
# 8     False
# 9      True
# 10    False
# 11    False
# 12    False
# 13     True
# 14     True
# 15     True
# 16     True
# 17    False
# 18    False
# 19     True
# Name: 0, dtype: bool

# %%
data[3]>500
# Out:
# 0     False
# 1      True
# 2     False
# 3     False
# 4     False
# 5     False
# 6      True
# 7      True
# 8     False
# 9     False
# 10     True
# 11     True
# 12    False
# 13     True
# 14    False
# 15    False
# 16    False
# 17     True
# 18     True
# 19     True
# Name: 3, dtype: bool

# %%
data = pd.read_csv("pr_data")

# %%
data
# Out:
#    Unnamed: 0 Customer       City Product  Sales  Profit  Quantity
# 0           0    Mohan      Delhi  Laptop  55000  8000.0         2
# 1           1    Rohan     Mumbai   Phone  20000  3000.0         5
# 2           2    Sohan      Delhi  Tablet  15000  2000.0         3
# 3           3     Aman  Bangalore  Laptop  60000  9000.0         1
# 4           4     Neha     Mumbai   Phone  22000  3200.0         4
# 5           5    Priya      Delhi  Tablet  14000  1800.0         2
# 6           6    Karan  Bangalore  Laptop  58000  8500.0         2
# 7           7    Rahul     Mumbai   Phone  21000     NaN         6

# %%
data.drop[0]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[76], line 1
# ----> 1 data.drop[0]
#
# TypeError: 'method' object is not subscriptable

# %%
data.drop(0)
# Out:
#    Unnamed: 0 Customer       City Product  Sales  Profit  Quantity
# 1           1    Rohan     Mumbai   Phone  20000  3000.0         5
# 2           2    Sohan      Delhi  Tablet  15000  2000.0         3
# 3           3     Aman  Bangalore  Laptop  60000  9000.0         1
# 4           4     Neha     Mumbai   Phone  22000  3200.0         4
# 5           5    Priya      Delhi  Tablet  14000  1800.0         2
# 6           6    Karan  Bangalore  Laptop  58000  8500.0         2
# 7           7    Rahul     Mumbai   Phone  21000     NaN         6

# %%
data.drop(0,axis=1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[78], line 1
# ----> 1 data.drop(0,axis=1)
#
# File c:\Users\Thisi\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\frame.py:5603, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5455 def drop(
#    5456     self,
#    5457     labels: IndexLabel | None = None,
#    (...)   5464     errors: IgnoreRaise = "raise",
#    5465 ) -> DataFrame | None:
#    5466     """
#    5467     Drop specified labels from rows or columns.
#    5468
#    (...)   5601             weight  1.0     0.8
#    5602     """
# -> 5603     return super().drop(
#    5604         labels=labels,
#    5605         axis=axis,
#    5606         index=index,
#    5607         columns=columns,
#    5608         level=level,
#    5609         inplace=inplace,
#    5610         errors=errors,
# ...

# %%
data.drop(0,axis=0)
# Out:
#    Unnamed: 0 Customer       City Product  Sales  Profit  Quantity
# 1           1    Rohan     Mumbai   Phone  20000  3000.0         5
# 2           2    Sohan      Delhi  Tablet  15000  2000.0         3
# 3           3     Aman  Bangalore  Laptop  60000  9000.0         1
# 4           4     Neha     Mumbai   Phone  22000  3200.0         4
# 5           5    Priya      Delhi  Tablet  14000  1800.0         2
# 6           6    Karan  Bangalore  Laptop  58000  8500.0         2
# 7           7    Rahul     Mumbai   Phone  21000     NaN         6

# %%
data.drop("Unnamed:0",axis=0)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[80], line 1
# ----> 1 data.drop("Unnamed:0",axis=0)
#
# File c:\Users\Thisi\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\frame.py:5603, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5455 def drop(
#    5456     self,
#    5457     labels: IndexLabel | None = None,
#    (...)   5464     errors: IgnoreRaise = "raise",
#    5465 ) -> DataFrame | None:
#    5466     """
#    5467     Drop specified labels from rows or columns.
#    5468
#    (...)   5601             weight  1.0     0.8
#    5602     """
# -> 5603     return super().drop(
#    5604         labels=labels,
#    5605         axis=axis,
#    5606         index=index,
#    5607         columns=columns,
#    5608         level=level,
#    5609         inplace=inplace,
#    5610         errors=errors,
# ...

# %%
data.groupby("Product")["Sales"].sum(
)
# Out:
# Product
# Laptop    173000
# Phone      63000
# Tablet     29000
# Name: Sales, dtype: int64

# %%
data.groupby("Product")["Sales"].max()
# Out:
# Product
# Laptop    60000
# Phone     22000
# Tablet    15000
# Name: Sales, dtype: int64

# %%
data.groupby("Product").agg({
    "Sales":"sum",
    "profit":"mean"
})
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[90], line 1
# ----> 1 data.groupby("Product").agg({
#       2     "Sales":"sum",
#       3     "profit":"mean"
#       4 })
#
# File c:\Users\Thisi\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\groupby\generic.py:1432, in DataFrameGroupBy.aggregate(self, func, engine, engine_kwargs, *args, **kwargs)
#    1429     kwargs["engine_kwargs"] = engine_kwargs
#    1431 op = GroupByApply(self, func, args=args, kwargs=kwargs)
# -> 1432 result = op.agg()
#    1433 if not is_dict_like(func) and result is not None:
#    1434     # GH #52849
#    1435     if not self.as_index and is_list_like(func):
#
# File c:\Users\Thisi\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\apply.py:190, in Apply.agg(self)
#     187     return self.apply_str()
#     189 if is_dict_like(func):
# ...

# %%
data
# Out:
#    Unnamed: 0 Customer       City Product  Sales  Profit  Quantity
# 0           0    Mohan      Delhi  Laptop  55000  8000.0         2
# 1           1    Rohan     Mumbai   Phone  20000  3000.0         5
# 2           2    Sohan      Delhi  Tablet  15000  2000.0         3
# 3           3     Aman  Bangalore  Laptop  60000  9000.0         1
# 4           4     Neha     Mumbai   Phone  22000  3200.0         4
# 5           5    Priya      Delhi  Tablet  14000  1800.0         2
# 6           6    Karan  Bangalore  Laptop  58000  8500.0         2
# 7           7    Rahul     Mumbai   Phone  21000     NaN         6

# %%
data.loc[data["Quantity"]<3]
# Out:
#    Unnamed: 0 Customer       City Product  Sales  Profit  Quantity
# 0           0    Mohan      Delhi  Laptop  55000  8000.0         2
# 3           3     Aman  Bangalore  Laptop  60000  9000.0         1
# 5           5    Priya      Delhi  Tablet  14000  1800.0         2
# 6           6    Karan  Bangalore  Laptop  58000  8500.0         2

# %%
data["Sales"]
# Out:
# 0    55000
# 1    20000
# 2    15000
# 3    60000
# 4    22000
# 5    14000
# 6    58000
# 7    21000
# Name: Sales, dtype: int64

# %%
data.iloc[[0]]
# Out:
#    Unnamed: 0 Customer   City Product  Sales  Profit  Quantity
# 0           0    Mohan  Delhi  Laptop  55000  8000.0         2

# %%
data[data["Profit"]>50]
# Out:
#    Unnamed: 0 Customer       City Product  Sales  Profit  Quantity
# 0           0    Mohan      Delhi  Laptop  55000  8000.0         2
# 1           1    Rohan     Mumbai   Phone  20000  3000.0         5
# 2           2    Sohan      Delhi  Tablet  15000  2000.0         3
# 3           3     Aman  Bangalore  Laptop  60000  9000.0         1
# 4           4     Neha     Mumbai   Phone  22000  3200.0         4
# 5           5    Priya      Delhi  Tablet  14000  1800.0         2
# 6           6    Karan  Bangalore  Laptop  58000  8500.0         2

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[103], line 1
# ----> 1 data[data.iloc["Sales"]>50]
#
# File c:\Users\Thisi\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\indexing.py:1192, in _LocationIndexer.__getitem__(self, key)
#    1190 maybe_callable = com.apply_if_callable(key, self.obj)
#    1191 maybe_callable = self._check_deprecated_callable_usage(key, maybe_callable)
# -> 1192 return self._getitem_axis(maybe_callable, axis=axis)
#
# File c:\Users\Thisi\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\indexing.py:1750, in _iLocIndexer._getitem_axis(self, key, axis)
#    1748 key = item_from_zerodim(key)
#    1749 if not is_integer(key):
# -> 1750     raise TypeError("Cannot index by location index with a non-integer key")
#    1752 # validate the location
#    1753 self._validate_integer(key, axis)
#
# ...

# %%
data[["Sales","Profit"]]
# Out:
#    Sales  Profit
# 0  55000  8000.0
# 1  20000  3000.0
# 2  15000  2000.0
# 3  60000  9000.0
# 4  22000  3200.0
# 5  14000  1800.0
# 6  58000  8500.0
# 7  21000     NaN

# %%
data.loc["Sales"]>100
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[106], line 1
# ----> 1 data.loc["Sales"]>100
#
# File c:\Users\Thisi\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\indexing.py:1192, in _LocationIndexer.__getitem__(self, key)
#    1190 maybe_callable = com.apply_if_callable(key, self.obj)
#    1191 maybe_callable = self._check_deprecated_callable_usage(key, maybe_callable)
# -> 1192 return self._getitem_axis(maybe_callable, axis=axis)
#
# File c:\Users\Thisi\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\indexing.py:1432, in _LocIndexer._getitem_axis(self, key, axis)
#    1430 # fall thru to straight lookup
#    1431 self._validate_key(key, axis)
# -> 1432 return self._get_label(key, axis=axis)
#
# ...

# %%
data[data["Sales"]>100]["Profit"]
# Out:
# 0    8000.0
# 1    3000.0
# 2    2000.0
# 3    9000.0
# 4    3200.0
# 5    1800.0
# 6    8500.0
# 7       NaN
# Name: Profit, dtype: float64

# %%
data[data["Sales"]>100]["Profit"]
# Out:
# 0    8000.0
# 1    3000.0
# 2    2000.0
# 3    9000.0
# 4    3200.0
# 5    1800.0
# 6    8500.0
# 7       NaN
# Name: Profit, dtype: float64

# %%
data[data["Sales"]>100]["Profit"]
# Out:
# 0    8000.0
# 1    3000.0
# 2    2000.0
# 3    9000.0
# 4    3200.0
# 5    1800.0
# 6    8500.0
# 7       NaN
# Name: Profit, dtype: float64

# %%
data[data["City"]=="Delhi"]
# Out:
#    Unnamed: 0 Customer   City Product  Sales  Profit  Quantity
# 0           0    Mohan  Delhi  Laptop  55000  8000.0         2
# 2           2    Sohan  Delhi  Tablet  15000  2000.0         3
# 5           5    Priya  Delhi  Tablet  14000  1800.0         2

# %%
data[data["Sales"]>50000]
# Out:
#    Unnamed: 0 Customer       City Product  Sales  Profit  Quantity
# 0           0    Mohan      Delhi  Laptop  55000  8000.0         2
# 3           3     Aman  Bangalore  Laptop  60000  9000.0         1
# 6           6    Karan  Bangalore  Laptop  58000  8500.0         2

# %%
data[["Customer","Product"]]
# Out:
#   Customer Product
# 0    Mohan  Laptop
# 1    Rohan   Phone
# 2    Sohan  Tablet
# 3     Aman  Laptop
# 4     Neha   Phone
# 5    Priya  Tablet
# 6    Karan  Laptop
# 7    Rahul   Phone

# %%
data["Product"]==["Laptop"]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[119], line 1
# ----> 1 data["Product"]==["Laptop"]
#
# File c:\Users\Thisi\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\ops\common.py:76, in _unpack_zerodim_and_defer.<locals>.new_method(self, other)
#      72             return NotImplemented
#      74 other = item_from_zerodim(other)
# ---> 76 return method(self, other)
#
# File c:\Users\Thisi\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\arraylike.py:40, in OpsMixin.__eq__(self, other)
#      38 @unpack_zerodim_and_defer("__eq__")
#      39 def __eq__(self, other):
# ---> 40     return self._cmp_method(other, operator.eq)
#
# File c:\Users\Thisi\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\series.py:6138, in Series._cmp_method(self, other, op)
#    6135 lvalues = self._values
# ...

# %%
data[data["Product"]=="Laptop"]
# Out:
#    Unnamed: 0 Customer       City Product  Sales  Profit  Quantity
# 0           0    Mohan      Delhi  Laptop  55000  8000.0         2
# 3           3     Aman  Bangalore  Laptop  60000  9000.0         1
# 6           6    Karan  Bangalore  Laptop  58000  8500.0         2

# %%
data[data["Profit"]>3000,["Customer"],["Sales"]
# Out:
#   Cell In[130], line 1
#     data[data["Profit"]>3000,["Customer"],["Sales"]
#                                                    ^
# _IncompleteInputError: incomplete input

# %%
data[data["Sales"]>3000][["Customer","Sales"]]
# Out:
#   Customer  Sales
# 0    Mohan  55000
# 1    Rohan  20000
# 2    Sohan  15000
# 3     Aman  60000
# 4     Neha  22000
# 5    Priya  14000
# 6    Karan  58000
# 7    Rahul  21000
