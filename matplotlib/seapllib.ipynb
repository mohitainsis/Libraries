# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as  plt
import seaborn as sns

# %%
x = [1,2,3,4,5,6,7,8]
y = [10,20,30,40,50,60,200,100]

plt.bar(x,y)
# Out:
# <BarContainer object of 8 artists>

# %%
plt.pie(x,labels="y")
plt.show(
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 plt.pie(x,labels="y")
#       2 plt.show(
#       3 )
#
# NameError: name 'plt' is not defined
