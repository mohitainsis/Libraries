# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.array([0,6])
y = np.array([10,250])

# %%
print(y)
# Out:
# [10 20]

# %%
plt.plot(x,y)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
