# %%
import numpy as np

# %%
arr = np.array([1,3,2,6,7,8])
print(arr)
# Out:
# [1 3 2 6 7 8]

# %%
print(type(arr))
# Out:
# <class 'numpy.ndarray'>

# %%
arr_2d = np.array([[1,2,3],[5,6,7]])
print(arr_2d)
print(arr_2d.ndim)
print(type(arr_2d))
# Out:
# [[1 2 3]
#  [5 6 7]]
# 2
# <class 'numpy.ndarray'>

# %%
arr_3d = np.array([[[1,2,3],1,3,5],[5,6,7],[6,7,8]]])
print(arr_3d)
# Out:
#   Cell In[6], line 1
#     arr_3d = np.array([[[1,2,3],1,3,5],[5,6,7],[6,7,8]]])
#                                                        ^
# SyntaxError: closing parenthesis ']' does not match opening parenthesis '('

# %%
arr_3d = np.array([[1,3,2],[5,5,5],
                   [[1,2,3],]]])

# %%
arr = np.array([1,2,3,4], ndim = 5)
print(arr)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 arr = np.array([1,2,3,4], ndim = 5)
#       2 print(arr)
#
# TypeError: array() got an unexpected keyword argument 'ndim'

# %%
print(arr_2d[1])
# Out:
# [5 6 7]

# %%
a = np.array([1,2,3,5,6])
print([2])
# Out:
# [2]

# %%
a = np.array([[1,2,3],[5,6,7]])
print(a.ndim)
print(a[0,2])
# Out:
# 2
# 3

# %%
arr_2d.dtype
# Out:
# dtype('int64')

# %%
sarr = np.array([1,2,3,5],dtype="S")
print(sarr)
sarr.dtype
# Out:
# [b'1' b'2' b'3' b'5']
# dtype('S1')

# %%
newiarr = sarr.astype("I")

# %%
newiarr.dtype
# Out:
# dtype('uint32')

# %%
sarr = sarr.astype(float)

# %%
sarr.dtype
# Out:
# dtype('float64')

# %%
sarr = sarr.astype(bool)

# %%
print(sarr)
# Out:
# [ True  True  True  True]

# %%
sarr.astype('int')
# Out:
# array([1, 1, 1, 1])

# %%
sarr = np.array([1,2,3,5])

# %%
sarr
# Out:
# array([1, 2, 3, 5])

# %%
c = sarr.copy()

# %%
c
# Out:
# array([1, 2, 3, 5])

# %%
sarr[0] = 13

# %%
sarr
# Out:
# array([13,  2,  3,  5])

# %%
v = sarr.view()

# %%
sarr[0] = 55
print(v)
# Out:
# [55  2  3  5]

# %%
v.base
# Out:
# array([55,  2,  3,  5])

# %%
v.copy
# Out:
# <function ndarray.copy>

# %%
fived = np.array([1,2,5,6],ndmin=5)
fived
# Out:
# array([[[[[1, 2, 5, 6]]]]])

# %%
fived.shape
# Out:
# (1, 1, 1, 1, 4)
